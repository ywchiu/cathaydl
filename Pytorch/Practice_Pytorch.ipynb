# %% [markdown]
# ## 練習題
# 目標: 建立一深度學習模型預測客戶是否流失

# %%
import pandas
df = pandas.read_csv('https://raw.githubusercontent.com/ywchiu/cathaydl/master/Data/Churn_Modelling.csv', header = 0 )
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df = df.iloc[:,3:]

# %%
geo = pandas.get_dummies(df['Geography']).drop('France', axis= 1)

# %%
gender = df['Gender'].replace({'Male':1, 'Female':0})

# %%
df2 = pandas.concat([geo, gender, df.drop(['Geography', 'Gender'], axis=1)], axis = 1)
df2.head()
# Out:
#    Germany  Spain  Gender  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 0        0      0       0          619   42       2       0.00              1
# 1        0      1       0          608   41       1   83807.86              1
# 2        0      0       0          502   42       8  159660.80              3
# 3        0      0       0          699   39       1       0.00              2
# 4        0      1       0          850   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# ## 問題1: 利用df 產生 X,y

# %% [markdown]
# ## 問題2: 請將資料區分為訓練與測試資料集

# %% [markdown]
# ## 問題3: 請將資料標準化

# %% [markdown]
# ##問題4: 使用Pytorch 建立深度學習模型預測客戶是否流失

# %% [markdown]
# ## 問題5: 評估模型準確度
